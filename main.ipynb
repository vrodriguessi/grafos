# %% [markdown]
# Visualização dos Grafos BHW - Etapa 1

# %%
# %% [markdown]
# # 📊 Análise de Grafos
# 
# Este notebook processa arquivos `.dat` e calcula estatísticas usando o algoritmo de Floyd-Warshall, além de métricas como diâmetro, caminho médio e intermediação.

# %%
from src.Grafos import Grafo
from src.utils.leitura_dados import parse_file_into_grafo
from src.algorithms.estatisticas import (
    calcular_estatisticas,
    calcular_caminho_medio,
    calcular_diametro,
    calcular_intermediacao
)
from src.algorithms.floyd_warshall import floyd_warshall
import os

# %%
def processar_arquivo(arquivo):
    print(f"📂 Processando o arquivo {arquivo}...\n")
    
    grafo = parse_file_into_grafo(arquivo)

    if not grafo:
        print(f"⚠️ Erro: O arquivo {arquivo} não contém dados válidos.")
        return

    print(f"✅ Grafo de {arquivo} carregado com sucesso!")

    estatisticas = calcular_estatisticas(grafo)
    dist, pred = floyd_warshall(grafo)

    caminho_medio = calcular_caminho_medio(dist)
    diametro = calcular_diametro(dist)

    print(f"\n📊 Estatísticas do Grafo {arquivo}:")
    for chave, valor in estatisticas.items():
        print(f"  {chave}: {valor}")
    
    print(f"  Caminho médio: {caminho_medio}")
    print(f"  Diametro: {diametro}")

    intermediacoes = calcular_intermediacao(dist, pred)
    intermediacao_dict = {i: valor for i, valor in enumerate(intermediacoes, 1)}
    print(f"  Intermediação: {intermediacao_dict}")

# %% [markdown]
# ## ▶️ Processar um arquivo específico

# %%
arquivo_teste = "data/selected_instances/BHW1.dat"
processar_arquivo(arquivo_teste)

# %% [markdown]
# ## 📁 Processar todos os arquivos da pasta

# %%
pasta_arquivos = "data/selected_instances"
arquivos = [f for f in os.listdir(pasta_arquivos) if f.endswith(".dat")]

for arquivo in arquivos:
    processar_arquivo(os.path.join(pasta_arquivos, arquivo))
# Out:
# <>:51: SyntaxWarning: invalid escape sequence '\s'
# <>:58: SyntaxWarning: invalid escape sequence '\s'
# <>:51: SyntaxWarning: invalid escape sequence '\s'
# <>:58: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Érika Mara\AppData\Local\Temp\ipykernel_5672\3588976234.py:51: SyntaxWarning: invalid escape sequence '\s'
#   arquivo_teste = "data\selected_instances\BHW1.dat"
# C:\Users\Érika Mara\AppData\Local\Temp\ipykernel_5672\3588976234.py:58: SyntaxWarning: invalid escape sequence '\s'
#   pasta_arquivos = "data\selected_instances"
# 📂 Processando o arquivo data\selected_instances\BHW1.dat...
#
# ✅ Grafo de data\selected_instances\BHW1.dat carregado com sucesso!
#
# 📊 Estatísticas do Grafo data\selected_instances\BHW1.dat:
#   Quantidade de vértices: 12
#   Quantidade de arestas obrigatórias: 11
#   Quantidade de arestas opcionais: 0
#   Quantidade total de arestas: 11
#   Quantidade de arcos obrigatórios: 11
#   Quantidade de arcos opcionais: 11
#   Quantidade total de arcos: 22
#   Quantidade de nós obrigatórios: 7
#   Grau mínimo dos vértices: 6
#   Grau máximo dos vértices: 10
#   Densidade do grafo: 0.25
#   Caminho médio: 16.71212121212121
#   Diametro: 30
#   Intermediação: {1: 18, 2: 22, 3: 6, 4: 0, 5: 14, 6: 38, 7: 22, 8: 16, 9: 14, 10: 6, 11: 0, 12: 22}
# 📂 Processando o arquivo data\selected_instances\BHW1.dat...
#
# ✅ Grafo de data\selected_instances\BHW1.dat carregado com sucesso!
#
# 📊 Estatísticas do Grafo data\selected_instances\BHW1.dat:
#   Quantidade de vértices: 12
#   Quantidade de arestas obrigatórias: 11
#   Quantidade de arestas opcionais: 0
#   Quantidade total de arestas: 11
#   Quantidade de arcos obrigatórios: 11
#   Quantidade de arcos opcionais: 11
#   Quantidade total de arcos: 22
#   Quantidade de nós obrigatórios: 7
#   Grau mínimo dos vértices: 6
#   Grau máximo dos vértices: 10
#   Densidade do grafo: 0.25
#   Caminho médio: 16.71212121212121
#   Diametro: 30
#   Intermediação: {1: 18, 2: 22, 3: 6, 4: 0, 5: 14, 6: 38, 7: 22, 8: 16, 9: 14, 10: 6, 11: 0, 12: 22}
# 📂 Processando o arquivo data\selected_instances\BHW10.dat...
#
# ✅ Grafo de data\selected_instances\BHW10.dat carregado com sucesso!
#
# 📊 Estatísticas do Grafo data\selected_instances\BHW10.dat:
#   Quantidade de vértices: 77
#   Quantidade de arestas obrigatórias: 0
#   Quantidade de arestas opcionais: 0
#   Quantidade total de arestas: 0
#   Quantidade de arcos obrigatórios: 102
#   Quantidade de arcos opcionais: 94
#   Quantidade total de arcos: 196
#   Quantidade de nós obrigatórios: 40
#   Grau mínimo dos vértices: 2
#   Grau máximo dos vértices: 8
#   Densidade do grafo: 0.03349282296650718
#   Caminho médio: 181.93574846206425
#   Diametro: 446
#   Intermediação: {1: 0, 2: 298, 3: 0, 4: 594, 5: 362, 6: 0, 7: 328, 8: 402, 9: 524, 10: 642, 11: 1210, 12: 786, 13: 80, 14: 32, 15: 270, 16: 126, 17: 0, 18: 934, 19: 1046, 20: 620, 21: 1426, 22: 1316, 23: 606, 24: 572, 25: 466, 26: 346, 27: 0, 28: 30, 29: 0, 30: 0, 31: 562, 32: 474, 33: 194, 34: 0, 35: 202, 36: 0, 37: 262, 38: 0, 39: 376, 40: 454, 41: 816, 42: 1142, 43: 718, 44: 1524, 45: 0, 46: 1362, 47: 1762, 48: 322, 49: 1700, 50: 738, 51: 1052, 52: 218, 53: 102, 54: 0, 55: 0, 56: 412, 57: 176, 58: 1178, 59: 1350, 60: 944, 61: 0, 62: 722, 63: 298, 64: 0, 65: 0, 66: 150, 67: 344, 68: 0, 69: 550, 70: 0, 71: 150, 72: 576, 73: 150, 74: 0, 75: 576, 76: 750, 77: 170}
# 📂 Processando o arquivo data\selected_instances\BHW2.dat...
#
# ✅ Grafo de data\selected_instances\BHW2.dat carregado com sucesso!
#
# 📊 Estatísticas do Grafo data\selected_instances\BHW2.dat:
#   Quantidade de vértices: 12
#   Quantidade de arestas obrigatórias: 0
#   Quantidade de arestas opcionais: 0
#   Quantidade total de arestas: 0
#   Quantidade de arcos obrigatórios: 25
#   Quantidade de arcos opcionais: 0
#   Quantidade total de arcos: 25
#   Quantidade de nós obrigatórios: 4
#   Grau mínimo dos vértices: 3
#   Grau máximo dos vértices: 6
#   Densidade do grafo: 0.1893939393939394
#   Caminho médio: 29.568181818181817
#   Diametro: 72
#   Intermediação: {1: 40, 2: 23, 3: 18, 4: 6, 5: 38, 6: 38, 7: 3, 8: 3, 9: 12, 10: 29, 11: 15, 12: 46}
# 📂 Processando o arquivo data\selected_instances\BHW3.dat...
#
# ✅ Grafo de data\selected_instances\BHW3.dat carregado com sucesso!
#
# 📊 Estatísticas do Grafo data\selected_instances\BHW3.dat:
#   Quantidade de vértices: 13
#   Quantidade de arestas obrigatórias: 8
#   Quantidade de arestas opcionais: 0
#   Quantidade total de arestas: 8
#   Quantidade de arcos obrigatórios: 7
#   Quantidade de arcos opcionais: 23
#   Quantidade total de arcos: 30
#   Quantidade de nós obrigatórios: 5
#   Grau mínimo dos vértices: 4
#   Grau máximo dos vértices: 10
#   Densidade do grafo: 0.24358974358974358
#   Caminho médio: 24.923076923076923
#   Diametro: 47
#   Intermediação: {1: 30, 2: 46, 3: 0, 4: 0, 5: 10, 6: 34, 7: 0, 8: 8, 9: 6, 10: 24, 11: 10, 12: 10, 13: 12}
# 📂 Processando o arquivo data\selected_instances\BHW4.dat...
#
# ✅ Grafo de data\selected_instances\BHW4.dat carregado com sucesso!
#
# 📊 Estatísticas do Grafo data\selected_instances\BHW4.dat:
#   Quantidade de vértices: 11
#   Quantidade de arestas obrigatórias: 0
#   Quantidade de arestas opcionais: 0
#   Quantidade total de arestas: 0
#   Quantidade de arcos obrigatórios: 44
#   Quantidade de arcos opcionais: 0
#   Quantidade total de arcos: 44
#   Quantidade de nós obrigatórios: 6
#   Grau mínimo dos vértices: 6
#   Grau máximo dos vértices: 10
#   Densidade do grafo: 0.4
#   Caminho médio: 3.6545454545454548
#   Diametro: 10
#   Intermediação: {1: 62, 2: 10, 3: 19, 4: 20, 5: 4, 6: 0, 7: 20, 8: 21, 9: 1, 10: 0, 11: 1}
# 📂 Processando o arquivo data\selected_instances\BHW5.dat...
#
# ✅ Grafo de data\selected_instances\BHW5.dat carregado com sucesso!
#
# 📊 Estatísticas do Grafo data\selected_instances\BHW5.dat:
#   Quantidade de vértices: 40
#   Quantidade de arestas obrigatórias: 0
#   Quantidade de arestas opcionais: 0
#   Quantidade total de arestas: 0
#   Quantidade de arcos obrigatórios: 132
#   Quantidade de arcos opcionais: 0
#   Quantidade total de arcos: 132
#   Quantidade de nós obrigatórios: 30
#   Grau mínimo dos vértices: 4
#   Grau máximo dos vértices: 16
#   Densidade do grafo: 0.08461538461538462
#   Caminho médio: 14.112820512820512
#   Diametro: 32
#   Intermediação: {1: 746, 2: 354, 3: 338, 4: 216, 5: 122, 6: 400, 7: 428, 8: 134, 9: 10, 10: 0, 11: 132, 12: 156, 13: 374, 14: 0, 15: 12, 16: 72, 17: 174, 18: 210, 19: 0, 20: 124, 21: 28, 22: 166, 23: 0, 24: 8, 25: 66, 26: 0, 27: 62, 28: 0, 29: 38, 30: 32, 31: 16, 32: 8, 33: 260, 34: 132, 35: 12, 36: 184, 37: 160, 38: 22, 39: 64, 40: 0}
# 📂 Processando o arquivo data\selected_instances\BHW6.dat...
#
# ✅ Grafo de data\selected_instances\BHW6.dat carregado com sucesso!
#
# 📊 Estatísticas do Grafo data\selected_instances\BHW6.dat:
#   Quantidade de vértices: 40
#   Quantidade de arestas obrigatórias: 37
#   Quantidade de arestas opcionais: 0
#   Quantidade total de arestas: 37
#   Quantidade de arcos obrigatórios: 58
#   Quantidade de arcos opcionais: 0
#   Quantidade total de arcos: 58
#   Quantidade de nós obrigatórios: 15
#   Grau mínimo dos vértices: 4
#   Grau máximo dos vértices: 16
#   Densidade do grafo: 0.060897435897435896
#   Caminho médio: 14.112820512820512
#   Diametro: 32
#   Intermediação: {1: 746, 2: 354, 3: 338, 4: 216, 5: 122, 6: 400, 7: 428, 8: 134, 9: 10, 10: 0, 11: 132, 12: 156, 13: 374, 14: 0, 15: 12, 16: 72, 17: 174, 18: 210, 19: 0, 20: 124, 21: 28, 22: 166, 23: 0, 24: 8, 25: 66, 26: 0, 27: 62, 28: 0, 29: 38, 30: 32, 31: 16, 32: 8, 33: 260, 34: 132, 35: 12, 36: 184, 37: 160, 38: 22, 39: 64, 40: 0}
# 📂 Processando o arquivo data\selected_instances\BHW7.dat...
#
# ✅ Grafo de data\selected_instances\BHW7.dat carregado com sucesso!
#
# 📊 Estatísticas do Grafo data\selected_instances\BHW7.dat:
#   Quantidade de vértices: 50
#   Quantidade de arestas obrigatórias: 0
#   Quantidade de arestas opcionais: 0
#   Quantidade total de arestas: 0
#   Quantidade de arcos obrigatórios: 194
#   Quantidade de arcos opcionais: 0
#   Quantidade total de arcos: 194
#   Quantidade de nós obrigatórios: 35
#   Grau mínimo dos vértices: 4
#   Grau máximo dos vértices: 10
#   Densidade do grafo: 0.07918367346938776
#   Caminho médio: 11.099591836734694
#   Diametro: 31
#   Intermediação: {1: 0, 2: 12, 3: 88, 4: 4, 5: 0, 6: 94, 7: 104, 8: 84, 9: 246, 10: 8, 11: 562, 12: 568, 13: 648, 14: 656, 15: 796, 16: 144, 17: 8, 18: 0, 19: 566, 20: 10, 21: 50, 22: 0, 23: 456, 24: 50, 25: 38, 26: 606, 27: 44, 28: 70, 29: 54, 30: 544, 31: 410, 32: 182, 33: 40, 34: 620, 35: 346, 36: 468, 37: 584, 38: 0, 39: 0, 40: 298, 41: 172, 42: 176, 43: 228, 44: 78, 45: 56, 46: 0, 47: 92, 48: 20, 49: 0, 50: 0}
# 📂 Processando o arquivo data\selected_instances\BHW8.dat...
#
# ✅ Grafo de data\selected_instances\BHW8.dat carregado com sucesso!
#
# 📊 Estatísticas do Grafo data\selected_instances\BHW8.dat:
#   Quantidade de vértices: 50
#   Quantidade de arestas obrigatórias: 0
#   Quantidade de arestas opcionais: 0
#   Quantidade total de arestas: 0
#   Quantidade de arcos obrigatórios: 97
#   Quantidade de arcos opcionais: 97
#   Quantidade total de arcos: 194
#   Quantidade de nós obrigatórios: 20
#   Grau mínimo dos vértices: 4
#   Grau máximo dos vértices: 10
#   Densidade do grafo: 0.07918367346938776
#   Caminho médio: 11.099591836734694
#   Diametro: 31
#   Intermediação: {1: 0, 2: 12, 3: 88, 4: 4, 5: 0, 6: 94, 7: 104, 8: 84, 9: 246, 10: 8, 11: 562, 12: 568, 13: 648, 14: 656, 15: 796, 16: 144, 17: 8, 18: 0, 19: 566, 20: 10, 21: 50, 22: 0, 23: 456, 24: 50, 25: 38, 26: 606, 27: 44, 28: 70, 29: 54, 30: 544, 31: 410, 32: 182, 33: 40, 34: 620, 35: 346, 36: 468, 37: 584, 38: 0, 39: 0, 40: 298, 41: 172, 42: 176, 43: 228, 44: 78, 45: 56, 46: 0, 47: 92, 48: 20, 49: 0, 50: 0}
# 📂 Processando o arquivo data\selected_instances\BHW9.dat...
#
# ✅ Grafo de data\selected_instances\BHW9.dat carregado com sucesso!
#
# 📊 Estatísticas do Grafo data\selected_instances\BHW9.dat:
#   Quantidade de vértices: 50
#   Quantidade de arestas obrigatórias: 26
#   Quantidade de arestas opcionais: 0
#   Quantidade total de arestas: 26
#   Quantidade de arcos obrigatórios: 142
#   Quantidade de arcos opcionais: 0
#   Quantidade total de arcos: 142
#   Quantidade de nós obrigatórios: 10
#   Grau mínimo dos vértices: 4
#   Grau máximo dos vértices: 10
#   Densidade do grafo: 0.06857142857142857
#   Caminho médio: 11.099591836734694
#   Diametro: 31
#   Intermediação: {1: 0, 2: 12, 3: 88, 4: 4, 5: 0, 6: 94, 7: 104, 8: 84, 9: 246, 10: 8, 11: 562, 12: 568, 13: 648, 14: 656, 15: 796, 16: 144, 17: 8, 18: 0, 19: 566, 20: 10, 21: 50, 22: 0, 23: 456, 24: 50, 25: 38, 26: 606, 27: 44, 28: 70, 29: 54, 30: 544, 31: 410, 32: 182, 33: 40, 34: 620, 35: 346, 36: 468, 37: 584, 38: 0, 39: 0, 40: 298, 41: 172, 42: 176, 43: 228, 44: 78, 45: 56, 46: 0, 47: 92, 48: 20, 49: 0, 50: 0}
